# %%
import pygame
import time
import random

# Initialize pygame
pygame.init()

# Set up display
width, height = 600, 400
win = pygame.display.set_mode((width, height))
pygame.display.set_caption("Snake Game by Kartik")

# Colors
white = (255, 255, 255)
black = (0, 0, 0)
red = (213, 50, 80)
green = (0, 255, 0)
blue = (50, 153, 213)

# Snake & Food size
block = 10
snake_speed = 10

# Fonts
font_style = pygame.font.SysFont("bahnschrift", 25)
score_font = pygame.font.SysFont("comicsansms", 20)

# Score function
def show_score(score):
    value = score_font.render(f"Score: {score}", True, black)
    win.blit(value, [10, 10])

# Snake function
def draw_snake(block, snake_list):
    for x in snake_list:
        pygame.draw.rect(win, black, [x[0], x[1], block, block])

# Message function
def message(msg, color):
    mesg = font_style.render(msg, True, color)
    win.blit(mesg, [width / 6, height / 3])

# Game loop
def gameLoop():
    game_over = False
    game_close = False

    # Start position
    x = width // 2
    y = height // 2
    x_change = 0
    y_change = 0

    snake_List = []
    Length_of_snake = 1

    # Food position
    food_x = round(random.randrange(0, width - block) / 10.0) * 10.0
    food_y = round(random.randrange(0, height - block) / 10.0) * 10.0

    clock = pygame.time.Clock()

    while not game_over:

        while game_close:
            win.fill(white)
            message("Game Over! Press Q-Quit or C-Play Again", red)
            show_score(Length_of_snake - 1)
            pygame.display.update()

            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_q:
                        game_over = True
                        game_close = False
                    if event.key == pygame.K_c:
                        gameLoop()

        # Movement keys
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                game_over = True
            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_LEFT:
                    x_change = -block
                    y_change = 0
                elif event.key == pygame.K_RIGHT:
                    x_change = block
                    y_change = 0
                elif event.key == pygame.K_UP:
                    y_change = -block
                    x_change = 0
                elif event.key == pygame.K_DOWN:
                    y_change = block
                    x_change = 0

        # Boundary condition
        if x >= width or x < 0 or y >= height or y < 0:
            game_close = True

        x += x_change
        y += y_change
        win.fill(blue)
        pygame.draw.rect(win, green, [food_x, food_y, block, block])

        snake_Head = []
        snake_Head.append(x)
        snake_Head.append(y)
        snake_List.append(snake_Head)

        if len(snake_List) > Length_of_snake:
            del snake_List[0]

        # Collision with self
        for segment in snake_List[:-1]:
            if segment == snake_Head:
                game_close = True

        draw_snake(block, snake_List)
        show_score(Length_of_snake - 1)
        pygame.display.update()

        # Collision with food
        if x == food_x and y == food_y:
            food_x = round(random.randrange(0, width - block) / 10.0) * 10.0
            food_y = round(random.randrange(0, height - block) / 10.0) * 10.0
            Length_of_snake += 1

        clock.tick(snake_speed)

    pygame.quit()
    quit()

# Run the game
gameLoop()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 135
#     132     quit()
#     134 # Run the game
# --> 135 gameLoop()
#
# Cell In[1], line 66, in gameLoop()
#      63 while not game_over:
#      65     while game_close:
# ---> 66         win.fill(white)
#      67         message("Game Over! Press Q-Quit or C-Play Again", red)
#      68         show_score(Length_of_snake - 1)
#
# error: display Surface quit

# %%
import pygame
print(pygame.__version__)
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2.6.1

# %%
# !pip install pygame
# Out:
# Collecting pygame
#   Obtaining dependency information for pygame from https://files.pythonhosted.org/packages/d2/55/ca3eb851aeef4f6f2e98a360c201f0d00bd1ba2eb98e2c7850d80aabc526/pygame-2.6.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.6 MB 825.8 kB/s eta 0:00:13
#     --------------------------------------- 0.1/10.6 MB 1.1 MB/s eta 0:00:10
#     --------------------------------------- 0.2/10.6 MB 1.5 MB/s eta 0:00:07
#    - -------------------------------------- 0.3/10.6 MB 1.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/10.6 MB 1.9 MB/s eta 0:00:06
#    -- ------------------------------------- 0.6/10.6 MB 2.1 MB/s eta 0:00:05
#    -- ------------------------------------- 0.7/10.6 MB 2.0 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/10.6 MB 2.3 MB/s eta 0:00:05
#    --- ------------------------------------ 1.1/10.6 MB 2.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.1/10.6 MB 2.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.2/10.6 MB 2.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/10.6 MB 2.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.5/10.6 MB 2.5 MB/s eta 0:00:04
#    ------ --------------------------------- 1.7/10.6 MB 2.5 MB/s eta 0:00:04
#    ------ --------------------------------- 1.9/10.6 MB 2.6 MB/s eta 0:00:04
#    ------- -------------------------------- 2.0/10.6 MB 2.6 MB/s eta 0:00:04
#    -------- ------------------------------- 2.2/10.6 MB 2.7 MB/s eta 0:00:04
#    --------- ------------------------------ 2.5/10.6 MB 2.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.7/10.6 MB 2.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/10.6 MB 2.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.1/10.6 MB 3.1 MB/s eta 0:00:03
#    ------------ --------------------------- 3.4/10.6 MB 3.1 MB/s eta 0:00:03
#    ------------- -------------------------- 3.7/10.6 MB 3.2 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/10.6 MB 3.3 MB/s eta 0:00:03
#    --------------- ------------------------ 4.1/10.6 MB 3.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.3/10.6 MB 3.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.5/10.6 MB 3.4 MB/s eta 0:00:02
#    ------------------ --------------------- 4.9/10.6 MB 3.5 MB/s eta 0:00:02
#    ------------------- -------------------- 5.2/10.6 MB 3.7 MB/s eta 0:00:02
#    -------------------- ------------------- 5.4/10.6 MB 3.7 MB/s eta 0:00:02
#    --------------------- ------------------ 5.8/10.6 MB 3.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.1/10.6 MB 3.9 MB/s eta 0:00:02
#    ------------------------ --------------- 6.4/10.6 MB 4.0 MB/s eta 0:00:02
#    ------------------------- -------------- 6.9/10.6 MB 4.2 MB/s eta 0:00:01
#    -------------------------- ------------- 7.1/10.6 MB 4.2 MB/s eta 0:00:01
#    --------------------------- ------------ 7.4/10.6 MB 4.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.5/10.6 MB 4.3 MB/s eta 0:00:01
#    ------------------------------- -------- 8.4/10.6 MB 4.5 MB/s eta 0:00:01
#    --------------------------------- ------ 8.9/10.6 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.2/10.6 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------ --- 9.6/10.6 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------- -- 10.0/10.6 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  10.4/10.6 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.6 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 5.1 MB/s eta 0:00:00
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1

# %%
import pygame
print(pygame.__version__)
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2.6.1
